# %% [markdown]
# # COGS 189 Analysis

# %%
# import matplotlib.patches as patches
# import seaborn as sns
# import scipy.signal as signal 
# import sklearn

# from scipy.io import loadmat
# from pathlib import Path
# from numpy import genfromtxt

import numpy as np   
import matplotlib.pyplot as plt    
import pandas as pd

import os
import mne

# %%
if(os.path.exists("out.txt")):
    os.remove("out.txt")
if(os.path.exists("out.csv")):
    os.remove("out.csv")

filename = "OpenBCI-RAW-2023-02-28_16-28-56.txt"
filename = "OpenBCI-RAW-2023-02-28_16-30-10.txt"

with open("../data/OpenBCISession_2023-02-28_16-27-31/" + filename, "r") as f:
    with open("out.txt", "w") as o:
        for line in f:
            if(line.startswith("S")):
                line = (line.replace(" ", "")).replace("Channel", "")
                o.write(line)
            elif("%" not in line):
                o.write(line)

os.rename("out.txt", "out.csv")

# %%
data = pd.read_csv("out.csv")
data.head()
# Out:
#    SampleIndex           EXG0           EXG1           EXG2           EXG3  \
# 0         27.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 1         28.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 2         29.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 3         30.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 4         31.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
#
#             EXG4           EXG5           EXG6           EXG7  Accel0  ...  \
# 0 -187500.022352 -187500.022352 -187500.022352 -187500.022352     0.0  ...
# 1 -187500.022352 -187500.022352 -187500.022352 -187500.022352     0.0  ...
# 2 -187500.022352 -187500.022352 -187500.022352 -187500.022352     0.0  ...
# 3 -187500.022352 -187500.022352 -187500.022352 -187500.022352     0.0  ...
# 4 -187500.022352 -187500.022352 -187500.022352 -187500.022352     0.0  ...
#
#    Other.3  Other.4  Other.5  Other.6  Analog0  Analog1  Analog2  \
# 0      0.0    236.0      1.0    255.0    315.0    236.0    511.0
# 1      0.0    236.0      1.0    254.0    315.0    236.0    510.0
# 2      0.0    236.0      1.0    254.0    315.0    236.0    510.0
# 3      0.0    236.0      1.0    255.0    315.0    236.0    511.0
# 4      0.0    236.0      1.0    255.0    316.0    236.0    511.0
#
#       Timestamp  Other.7      Timestamp(Formatted)
# 0  1.677631e+09      0.0   2023-02-28 16:30:10.619
# 1  1.677631e+09      0.0   2023-02-28 16:30:10.619
# 2  1.677631e+09      0.0   2023-02-28 16:30:10.619
# 3  1.677631e+09      0.0   2023-02-28 16:30:10.619
# 4  1.677631e+09      0.0   2023-02-28 16:30:10.619
#
# [5 rows x 25 columns]

# %%
#testing channel values

print("Accel0 Size: " + str(len(data.loc[data['Accel0'] != 0])))
print("Accel1 Size: " + str(len(data.loc[data['Accel1'] != 0])))
print("Accel2 Size: " + str(len(data.loc[data['Accel2'] != 0])))

print()

print("Analog0 Size: " + str(len(data.loc[data['Analog0'] != 0])))
print("Analog1 Size: " + str(len(data.loc[data['Analog1'] != 0])))
print("Analog2 Size: " + str(len(data.loc[data['Analog2'] != 0])))
# Out:
# Accel0 Size: 0
# Accel1 Size: 0
# Accel2 Size: 0
#
# Analog0 Size: 10678
# Analog1 Size: 10678
# Analog2 Size: 10678

# %%
# data = data.drop(columns=['temp', 'time0'])
#data = data.drop(columns=['temp', 'time0', 'time1'])
data = data[['EXG0', 'EXG1', 'EXG2', 'EXG3', 'EXG4', 'EXG5', 'EXG6', 'EXG7', 
             'Analog0', 'Analog1', 'Analog2', 'Timestamp']]
data = data.T
data
# Out:
#                   0             1             2             3      \
# EXG0      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG1      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG2      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG3      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG4      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG5      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG6      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG7      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# Analog0    3.150000e+02  3.150000e+02  3.150000e+02  3.150000e+02
# Analog1    2.360000e+02  2.360000e+02  2.360000e+02  2.360000e+02
# Analog2    5.110000e+02  5.100000e+02  5.100000e+02  5.110000e+02
# Timestamp  1.677631e+09  1.677631e+09  1.677631e+09  1.677631e+09
#
#                   4             5             6             7      \
# EXG0      -1.875000e+05  0.000000e+00 -1.875000e+05 -1.875000e+05
# EXG1      -1.875000e+05  0.000000e+00 -1.875000e+05 -1.875000e+05
# EXG2      -1.875000e+05  0.000000e+00 -1.875000e+05 -1.875000e+05
# EXG3      -1.875000e+05  0.000000e+00 -1.875000e+05 -1.875000e+05
# EXG4      -1.875000e+05  0.000000e+00 -1.875000e+05 -1.875000e+05
# EXG5      -1.875000e+05  0.000000e+00 -1.875000e+05 -1.875000e+05
# EXG6      -1.875000e+05  0.000000e+00 -1.875000e+05 -1.875000e+05
# EXG7      -1.875000e+05  0.000000e+00 -1.875000e+05 -1.875000e+05
# Analog0    3.160000e+02  4.390000e+02  4.190000e+02  3.970000e+02
# Analog1    2.360000e+02  7.660000e+02  6.190000e+02  5.120000e+02
# Analog2    5.110000e+02  5.110000e+02  5.110000e+02  5.110000e+02
# Timestamp  1.677631e+09  1.677631e+09  1.677631e+09  1.677631e+09
#
#                   8             9      ...         10668         10669  \
# EXG0      -1.875000e+05 -1.875000e+05  ... -1.631467e+05 -1.631395e+05
# EXG1      -1.875000e+05 -1.875000e+05  ... -1.625444e+05 -1.625382e+05
# EXG2      -1.875000e+05 -1.875000e+05  ... -1.690324e+05 -1.690259e+05
# EXG3      -1.875000e+05 -1.875000e+05  ... -1.707982e+05 -1.707917e+05
# EXG4      -1.875000e+05 -1.875000e+05  ... -1.875000e+05 -1.875000e+05
# EXG5      -1.875000e+05 -1.875000e+05  ... -1.875000e+05 -1.875000e+05
# EXG6      -1.875000e+05 -1.875000e+05  ... -1.875000e+05 -1.875000e+05
# EXG7      -1.875000e+05 -1.875000e+05  ... -1.875000e+05 -1.875000e+05
# Analog0    3.810000e+02  3.680000e+02  ...  3.150000e+02  3.150000e+02
# Analog1    4.380000e+02  3.850000e+02  ...  2.360000e+02  2.350000e+02
# Analog2    5.110000e+02  5.110000e+02  ...  5.110000e+02  5.110000e+02
# Timestamp  1.677631e+09  1.677631e+09  ...  1.677631e+09  1.677631e+09
#
#                   10670         10671         10672         10673  \
# EXG0      -1.631330e+05 -1.631308e+05 -1.631244e+05 -1.631162e+05
# EXG1      -1.625323e+05 -1.625304e+05 -1.625247e+05 -1.625174e+05
# EXG2      -1.690198e+05 -1.690176e+05 -1.690118e+05 -1.690042e+05
# EXG3      -1.707854e+05 -1.707831e+05 -1.707772e+05 -1.707697e+05
# EXG4      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG5      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG6      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG7      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# Analog0    3.160000e+02  3.150000e+02  3.150000e+02  3.150000e+02
# Analog1    2.360000e+02  2.360000e+02  2.350000e+02  2.360000e+02
# Analog2    5.110000e+02  5.100000e+02  5.110000e+02  5.110000e+02
# Timestamp  1.677631e+09  1.677631e+09  1.677631e+09  1.677631e+09
#
#                   10674         10675         10676         10677
# EXG0      -1.631121e+05 -1.631091e+05 -1.631052e+05 -1.631011e+05
# EXG1      -1.625140e+05 -1.625114e+05 -1.625080e+05 -1.625048e+05
# EXG2      -1.690004e+05 -1.689977e+05 -1.689941e+05 -1.689908e+05
# EXG3      -1.707659e+05 -1.707630e+05 -1.707594e+05 -1.707560e+05
# EXG4      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG5      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG6      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG7      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# Analog0    3.150000e+02  3.150000e+02  3.150000e+02  3.160000e+02
# Analog1    2.360000e+02  2.360000e+02  2.360000e+02  2.350000e+02
# Analog2    5.110000e+02  5.110000e+02  5.100000e+02  5.110000e+02
# Timestamp  1.677631e+09  1.677631e+09  1.677631e+09  1.677631e+09
#
# [12 rows x 10678 columns]

# %%
print("Analog0 Min: " + str(data.T['Analog0'][100:].min()))
print("Analog0 Max: " + str(data.T['Analog0'][100:].max()))

print("Analog1 Min: " + str(data.T['Analog1'][100:].min()))
print("Analog1 Max: " + str(data.T['Analog1'][100:].max()))

print("Analog2 Min: " + str(data.T['Analog2'][100:].min()))
print("Analog2 Max: " + str(data.T['Analog2'][100:].max()))

plt.figure(figsize=(15,9))
plt.title("Analog Channels Comparison", fontsize=15)
plt.plot(data.T['Analog0'][100:], label="Analog0")
plt.plot(data.T['Analog1'][100:], label="Analog1")
plt.plot(data.T['Analog2'][100:], label="Analog2")
plt.legend(loc="upper left")
plt.show()
# Out:
# Analog0 Min: 296.0
# Analog0 Max: 333.0
# Analog1 Min: 228.0
# Analog1 Max: 243.0
# Analog2 Min: 331.0
# Analog2 Max: 712.0

# %%
sampleRate = 250.0
sfreq = 1000
ch_types = []
ch_names = []

num_channels = data.shape[0]
num_eeg = 8
num_aux = 3
num_time = 1
eeg_channel = "eeg"
aux_channel = "stim" #change
time_channel = "misc" #change

for i in range(num_eeg):
    ch_types.append(eeg_channel)
for i in range(num_aux):
    ch_types.append(aux_channel)
for i in range(num_time):
    ch_types.append(time_channel)  

info = mne.create_info(ch_names=list(data.index), sfreq=sfreq, ch_types=ch_types)

# %%
raw = mne.io.RawArray(data, info)
raw
# Out:
# Creating RawArray with float64 data, n_channels=12, n_times=10678
#     Range : 0 ... 10677 =      0.000 ...    10.677 secs
# Ready.
# <RawArray | 12 x 10678 (10.7 s), ~1018 kB, data loaded>

# %%
scalings = {'eeg': 2, 'bio': 1, 'time': 1}

raw.plot(n_channels=11, scalings=scalings, title='test',
         show=True, block=True)


raw.compute_psd().plot(average = False)
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 576x576 with 4 Axes>
# Effective window size : 0.256 (s)
# /var/folders/8y/bgrdr4yj1vx1k4ng25rfrptw0000gn/T/ipykernel_839/1906968303.py:7: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.compute_psd().plot(average = False)
# /Users/sashgollamudi/opt/anaconda3/lib/python3.9/site-packages/mne/viz/utils.py:137: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 720x252 with 1 Axes>
# <MNELineFigure size 720x252 with 1 Axes>
