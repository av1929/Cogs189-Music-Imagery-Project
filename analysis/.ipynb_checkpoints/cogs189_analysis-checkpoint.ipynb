# %% [markdown]
# # COGS 189 Analysis

# %%
# import matplotlib.patches as patches
# import seaborn as sns
# import scipy.signal as signal 
# import sklearn

# from scipy.io import loadmat
# from pathlib import Path
# from numpy import genfromtxt

import numpy as np   
import matplotlib.pyplot as plt    
import pandas as pd
import os

import mne

# %%
sampleRate = 250.0

if(os.path.exists("out.txt")):
    os.remove("out.txt")
if(os.path.exists("out.csv")):
    os.remove("out.csv")
    
# with open("../data/OpenBCISession_2023-02-28_16-27-31/OpenBCI-RAW-2023-02-28_16-30-10.txt", "r") as f:
with open("../data/OpenBCISession_2023-02-28_16-27-31/OpenBCI-RAW-2023-02-28_16-28-56.txt", "r") as f:
    with open("out.txt", "w") as o:
        #o.write("temp,eeg0,eeg1,eeg2,eeg3,eeg4,eeg5,eeg6,eeg7,aux0,aux1,aux2,time0,time1\n")
        for line in f:
            if(line.startswith("S")):
                line = (line.replace(" ", "")).replace("Channel", "")
                o.write(line)
            elif("%" not in line):
                o.write(line)

os.rename("out.txt", "out.csv")

# %%
data = pd.read_csv("out.csv")
data.head()
# Out:
#    SampleIndex           EXG0           EXG1           EXG2           EXG3  \
# 0          0.0       0.000000       0.000000       0.000000       0.000000
# 1          1.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 2          2.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 3          3.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
# 4          4.0 -187500.022352 -187500.022352 -187500.022352 -187500.022352
#
#             EXG4           EXG5           EXG6           EXG7  Accel0  ...  \
# 0       0.000000       0.000000       0.000000       0.000000     0.0  ...
# 1 -187500.022352 -187500.022352 -187500.022352 -187500.022352     0.0  ...
# 2 -187500.022352 -187500.022352 -187500.022352 -187500.022352     0.0  ...
# 3 -187500.022352 -187500.022352 -187500.022352 -187500.022352     0.0  ...
# 4 -187500.022352 -187500.022352 -187500.022352 -187500.022352     0.0  ...
#
# ...

# %%
# filter = data["Accel0"]==0
  
# # filtering data
# data.where(filter, inplace = True)

# df2=data.where(data['SampleList'] == 0)
# data

print(data.loc[data['Accel0'] != 0])
print(data.loc[data['Accel1'] != 0])
print(data.loc[data['Accel2'] != 0])

print("Analog0 Min: " + str(data['Analog0'].min()))
print("Analog1 Max: " + str(data['Analog1'].max()))
print("Analog2 Min: " + str(data['Analog2'].min()))
print("Analog0 Max: " + str(data['Analog0'].max()))
print("Analog1 Min: " + str(data['Analog1'].min()))
print("Analog2 Max: " + str(data['Analog2'].max()))
# Out:
# Empty DataFrame
# Columns: [SampleIndex, EXG0, EXG1, EXG2, EXG3, EXG4, EXG5, EXG6, EXG7, Accel0, Accel1, Accel2, Other, Other.1, Other.2, Other.3, Other.4, Other.5, Other.6, Analog0, Analog1, Analog2, Timestamp, Other.7, Timestamp(Formatted)]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [SampleIndex, EXG0, EXG1, EXG2, EXG3, EXG4, EXG5, EXG6, EXG7, Accel0, Accel1, Accel2, Other, Other.1, Other.2, Other.3, Other.4, Other.5, Other.6, Analog0, Analog1, Analog2, Timestamp, Other.7, Timestamp(Formatted)]
# Index: []
#
# [0 rows x 25 columns]
# Empty DataFrame
# Columns: [SampleIndex, EXG0, EXG1, EXG2, EXG3, EXG4, EXG5, EXG6, EXG7, Accel0, Accel1, Accel2, Other, Other.1, Other.2, Other.3, Other.4, Other.5, Other.6, Analog0, Analog1, Analog2, Timestamp, Other.7, Timestamp(Formatted)]
# Index: []
#
# [0 rows x 25 columns]
# Analog0 Min: 314.0
# Analog1 Max: 776.0
# Analog2 Min: 503.0
# Analog0 Max: 504.0
# Analog1 Min: 235.0
# Analog2 Max: 519.0

# %%
# data = data.drop(columns=['temp', 'time0'])
#data = data.drop(columns=['temp', 'time0', 'time1'])
data = data[['EXG0', 'EXG1', 'EXG2', 'EXG3', 'EXG4', 'EXG5', 'EXG6', 'EXG7', 'Analog0', 'Analog1', 'Analog2', 'Timestamp']]
data = data.T
data
# Out:
#                   0             1             2             3      \
# EXG0      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG1      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG2      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG3      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG4      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG5      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG6      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# EXG7      -1.875000e+05 -1.875000e+05 -1.875000e+05 -1.875000e+05
# Analog0    3.150000e+02  3.150000e+02  3.150000e+02  3.150000e+02
# Analog1    2.360000e+02  2.360000e+02  2.360000e+02  2.360000e+02
# Analog2    5.110000e+02  5.100000e+02  5.100000e+02  5.110000e+02
# Timestamp  1.677631e+09  1.677631e+09  1.677631e+09  1.677631e+09
#
#                   4             5             6             7      \
# ...

# %%
sfreq = 1000
ch_types = []
ch_names = []

num_channels = data.shape[0]
num_eeg = 8
num_aux = 3
num_time = 1
eeg_channel = "eeg"
aux_channel = "stim" #change
time_channel = "misc" #change

for i in range(num_eeg):
    ch_types.append(eeg_channel)
for i in range(num_aux):
    ch_types.append(aux_channel)
for i in range(num_time):
    ch_types.append(time_channel)  

info = mne.create_info(ch_names=list(data.index), sfreq=sfreq, ch_types=ch_types)

# %%
raw = mne.io.RawArray(data, info)
# Out:
# Creating RawArray with float64 data, n_channels=12, n_times=10678
#     Range : 0 ... 10677 =      0.000 ...    10.677 secs
# Ready.

# %%
raw
# Out:
# <RawArray | 12 x 10678 (10.7 s), ~1018 kB, data loaded>

# %%
scalings = {'eeg': 2, 'bio': 1, 'time': 1}

raw.plot(n_channels=11, scalings=scalings, title='test',
         show=True, block=True)


raw.compute_psd().plot(average = False)
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 576x576 with 4 Axes>
# Effective window size : 0.256 (s)
# /var/folders/8y/bgrdr4yj1vx1k4ng25rfrptw0000gn/T/ipykernel_1411/1906968303.py:7: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.compute_psd().plot(average = False)
# /Users/sashgollamudi/opt/anaconda3/lib/python3.9/site-packages/mne/viz/utils.py:137: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 720x252 with 1 Axes>
